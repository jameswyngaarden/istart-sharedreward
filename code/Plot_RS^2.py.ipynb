# %%
import pandas as pd

import seaborn as sns

covariates = pd.read_excel("C:/Users/tul03789/Documents/GitHub/UGDG_Analysis/code/final_output_composite.xls")

usedir = "C:/Users/tul03789/Documents/GitHub/UGDG_Analysis/derivatives/imaging_plots_2/"
ROI= "seed-ACC-10mm" #seed-vmPFC-5mm-thr_ seed-NAcc_ seed-dlPFC-thr 

model_type= "_type-ppi_seed-NAcc_" # type-ppi_seed-NAcc_"
covariate = "cov-COMPOSITE_"
model = "noINT_model-GLM3_" # use noINT_model-GLM3_ for no interactions

import_model = ("C:/Users/tul03789/Documents/GitHub/UGDG_Analysis/derivatives/imaging_plots_2/UGP.csv")
UGP_model = pd.read_csv(import_model)
                           
cov =(covariates['Composite_Reward_Squared'])
act =(UGP_model['UGP'])

test = pd.DataFrame().assign(Composite_Reward=covariates['Composite_Reward'], UGP=UGP_model['UGP'])

fig=sns.lmplot(y="UGP",x="Composite_Reward", data=test, order=2)
