# %%
import os
import numpy as np
import pandas as pd
import re
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

usedir = '../derivatives/fsl/L3_model-2_task-sharedreward_n45_flame1_SFN_edition/'
os.chdir(usedir)

# %%
coordinates_flist=[os.path.join(root, f) for root, dirs, files in os.walk('logs') for f in files if 'SR-Rating' in f]
filename = 'L3_task-sharedreward_type-act_cnum-02_cname-C_rew_onegroup.gfeat/cope1.feat/cluster_zstat1_std.txt'
contrast = re.search(filename, 'cname-(.*).gfeat').group(1), 'type-(.*).gfeat').group(1), 
regressor
df = pd.read_csv(filename, delimiter='\t')
df
# Out:
#     Cluster Index  Voxels             P  -log10(P)  Z-MAX  Z-MAX X (mm)  \
# 0              11    3509  0.000000e+00      63.40   7.90         -36.5
# 1              10     959  1.350000e-26      25.90   6.87         -30.5
# 2               9     708  1.340000e-21      20.90   5.78         -15.5
# 3               8     692  2.910000e-21      20.50   6.88          50.5
# 4               7     436  1.910000e-15      14.70   5.80          32.5
# 5               6     243  3.070000e-10       9.51   5.45          47.5
# 6               5     185  2.010000e-08       7.70   5.39           2.5
# 7               4     141  6.560000e-07       6.18   5.08          14.5
# 8               3      80  1.590000e-04       3.80   5.53          11.5
# 9               2      41  1.180000e-02       1.93   4.68         -48.5
# 10              1      39  1.520000e-02       1.82   4.34         -39.5
#
#     Z-MAX Y (mm)  Z-MAX Z (mm)  Z-COG X (mm)  Z-COG Y (mm)  Z-COG Z (mm)  \
# ...
